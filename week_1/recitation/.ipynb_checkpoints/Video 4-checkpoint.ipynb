# %%
# %matplotlib inline

# %%
import pandas as pd

# %% [markdown]
# Let us print the Pandas version

# %%
pd.__version__
# Out:
# '0.13.1'

# %% [markdown]
# Reading the CSV stored in the `data` folder

# %%
usda = pd.read_csv("../data/USDA.csv")

# %% [markdown]
# Plotting `Protein` vs `Fat`

# %%
usda.plot(kind="scatter",x="Protein",y="TotalFat");

# %% [markdown]
# Histogram of `Vitamin C` levels

# %%
usda.VitaminC.hist();

# %% [markdown]
# Histogram for first 100 entries

# %%
usda.VitaminC[usda.VitaminC<100].hist(bins=100);

# %% [markdown]
# Creating a boxplot for sugar

# %%
usda.boxplot(column="Sugar");
